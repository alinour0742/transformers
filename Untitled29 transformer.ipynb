# %%
import numpy as np

tokens = ["What", "are", "the", "symptoms", "of", "diabetes"]

np.random.seed(0)


d_model = 4


X = np.random.rand(len(tokens), d_model)


W_Q = np.random.rand(d_model, d_model)
W_K = np.random.rand(d_model, d_model)
W_V = np.random.rand(d_model, d_model)


Q = X @ W_Q
K = X @ W_K
V = X @ W_V

scores = Q @ K.T / np.sqrt(d_model)


def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=1, keepdims=True)


attention_weights = softmax(scores)


output = attention_weights @ V

print("Attention Weights:\n", attention_weights)
print("\nOutput:\n", output)
# Out:
# Attention Weights:
#  [[0.15613313 0.14733286 0.18837221 0.07784161 0.17859356 0.25172663]
#  [0.15385631 0.14383864 0.19405694 0.07189619 0.17312872 0.2632232 ]
#  [0.15621729 0.14442858 0.18935584 0.07590575 0.17950171 0.25459083]
#  [0.16242608 0.15649727 0.18144369 0.10382821 0.17974393 0.21606081]
#  [0.15191587 0.14507351 0.19014811 0.06849637 0.17528916 0.26907698]
#  [0.15143574 0.13813405 0.1956768  0.06269177 0.17613446 0.27592718]]
#
# Output:
#  [[1.19597058 0.509796   1.87645234 0.62074247]
#  [1.20483512 0.51322278 1.88379266 0.62427468]
#  [1.19789431 0.51076633 1.87902701 0.62161114]
#  [1.1677596  0.49953651 1.8445781  0.60767295]
#  [1.20826892 0.51379191 1.88876339 0.62630745]
#  [1.21418479 0.5168282  1.89576543 0.62879477]]
